# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.4.0'

# %%
# !ls #bash commands directly in the notebook
# Out:
# Playground.ipynb

# %%
#img = cv2.imread('../../Datasets/img/day1.jpg') 
img = cv2.imread('../../Datasets/img/day1.jpg',cv2.IMREAD_GRAYSCALE) #after path we can process it 
# make it faster by greyscale or downscalling

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (5472, 3648)

# %%
img
# Out:
# array([[64, 65, 64, ..., 50, 49, 48],
#        [66, 66, 64, ..., 51, 51, 51],
#        [66, 65, 63, ..., 52, 53, 53],
#        ...,
#        [39, 40, 41, ..., 39, 37, 37],
#        [37, 38, 40, ..., 39, 39, 38],
#        [35, 37, 39, ..., 40, 39, 39]], dtype=uint8)
