# %% [markdown]
# # Transformations

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def imshow(img):
    plt.figure(figsize = (10,7))
    plt.imshow(img)

# %% [markdown]
# ### Translations

# %%
# !ls img
# Out:
# 4.png                day4.jpg             noisy.png
# blue-flowers.jpg     fry.png              notes.png
# blue-red-flowers.png n.png                purple-flowers.jpg
# clean-text.jpg       night                scan.jpg
# day                  night1.jpg           sketch.png
# day1.jpg             night2.jpg           text.png
# day2.jpg             night3.png
# day3.jpg             night4.jpg

# %%
# Load an image
img = cv2.imread('img/fry.png')
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
imshow(rgb_img)

# %%
# Store the height and width of the image (you will need them later)
h, w = rgb_img.shape[:2]

# %%
# Create the translation Matrix
translation_matrix = np.float32([
    [1,0,-25],
    [0,1,-50]
])

# %%
# Apply the translation to the image using cv2.warpAffine and display the new image
img_moved  = cv2.warpAffine(rgb_img,translation_matrix,(w,h))
imshow(img_moved)

# %% [markdown]
# ### Rotation

# %%
# Load an image

# Create a rotation matrix to rotate the image by 45 degrees (using the center as the pivot point) 
x_center = w//2
y_center = h//2
rotation_matrix = cv2.getRotationMatrix2D((x_center,y_center),45,1)
rotation_matrix
# Out:
# array([[  0.70710678,   0.70710678, -30.80613255],
#        [ -0.70710678,   0.70710678, 119.627417  ]])

# %% [markdown]
# [Hint](# "cv2.getRotationMatrix2D")

# %%
# Apply the rotation matrix to the image and display the rotated image
img_rotated = cv2.warpAffine(rgb_img,rotation_matrix,(w,h))
imshow(img_rotated)

# %% [markdown]
# ### Scaling images

# %% [markdown]
# #### Interpolation methods

# %% [markdown]
# * INTER_NEAREST - a nearest-neighbor interpolation (Fastest)
# * INTER_LINEAR - a bilinear interpolation (used by default) (good for upsampling)
# * INTER_AREA - resampling using pixel area relation. It may be a preferred method for image decimation, as it gives moire’-free results. But when the image is zoomed, it is similar to the INTER_NEAREST method. (Good for downsampling)
# * INTER_CUBIC - a bicubic interpolation over 4x4 pixel neighborhood (Better)
# * INTER_LANCZOS4 - a Lanczos interpolation over 8x8 pixel neighborhood (Best one)

# %% [markdown]
# #### Downsampling

# %%
imshow(rgb_img)

# %%
# Load and image and downsample it by half, try all the interpolation methods
# which one renders the best result?
new_width = w//2
new_height = h//2
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_NEAREST)
imshow(img_half_size)

# %%
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_LINEAR)
imshow(img_half_size)

# %%
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_AREA)
imshow(img_half_size)

# %%
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_CUBIC)
imshow(img_half_size)

# %%
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_LANCZOS4)
imshow(img_half_size)

# %% [markdown]
# [Hint](# "cv2.resize")

# %% [markdown]
# #### Upsampling

# %%
# Load and image and upsample it by double its size, try all the interpolation methods 
# which one renders the best result?
new_width = w*2
new_height = h*2
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_NEAREST)
imshow(img_half_size)

# %%
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_LINEAR)
imshow(img_half_size)

# %%
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_AREA)
imshow(img_half_size)

# %%
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_CUBIC)
imshow(img_half_size)

# %%
img_half_size = cv2.resize(rgb_img, (new_width , new_height), interpolation = cv2.INTER_LANCZOS4)
imshow(img_half_size)
