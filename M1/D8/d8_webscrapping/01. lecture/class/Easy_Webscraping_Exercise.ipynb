# %% [markdown]
# Exercise Easy:
#
#     Extract the 6 days weather from san Francisco in weather.gov.
#
#     1.inspect with the console
#     2.write code to target the right elements of the text
#     3.For each day, you need to store:
#
#     -The day of the week (Saturday)
#
#     -The date (12/09)
#
#     -A short description of the conditions (Clear early then increasing        cloudiness after midnight. Low 41F. Winds light and variable)
#
#     -The temperature low and high, with a function of your own to convert      into Celsius
#
#     -For each element you scrape, The name of the item you targetted (ex:      DailyContent--daypartDate--3MM0J)
#
#     -Save all of this into a Pandas dataframe

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import date

# %%
page = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.X9DVpBakolQ")
soup = BeautifulSoup(page.content, 'html.parser') #whole html
#html = list(soup.children)[2] #whole html nicer format #concept children parent in web dev
#body = list(html.children)[3] #[in get sibling]
#main = list(body.children)[1] #one deeper in main
#print(body)
#print(main)

period_name_container = soup.find_all('div',class_= "col-sm-2 forecast-label")
#print(period_name_container)

description_container = soup.find_all("div", class_= "forecast-text")
#print(description_container)

# %%
#print(period_name_container)
days = []
for b in period_name_container:
    days.append(b.getText()) #if its in a div -> first b = div/second b = div.find('b')
print(days)
# Out:
# ['This Afternoon', 'Tonight', 'Thursday', 'Thursday Night', 'Friday', 'Friday Night', 'Saturday', 'Saturday Night', 'Sunday', 'Sunday Night', 'Monday', 'Monday Night', 'Tuesday']

# %%
description = []
for div in description_container:
    description.append(div.getText())
print(description)
# Out:
# ['Mostly sunny, with a high near 66. North wind 5 to 13 mph becoming west. ', 'Partly cloudy, with a low around 48. West wind 10 to 17 mph, with gusts as high as 23 mph. ', 'Sunny, with a high near 61. West wind 7 to 17 mph, with gusts as high as 23 mph. ', 'Clear, with a low around 46. Northwest wind 5 to 14 mph, with gusts as high as 18 mph. ', 'Sunny, with a high near 69. North wind 8 to 10 mph. ', 'Clear, with a low around 47.', 'Sunny, with a high near 74.', 'Clear, with a low around 49.', 'Sunny, with a high near 69.', 'Mostly clear, with a low around 49.', 'Sunny, with a high near 66.', 'Clear, with a low around 48.', 'Sunny, with a high near 69.']

# %%
temps = [] #get the temperature from the description text 
for i in range(len(description)): #iterate in list
    desc = description[i]         #acces list index
    desc = desc.split('.')        #split the first sentence if it is one
    desc = desc[0]                #take only the first sentence
    desc = desc.split()           #split sentence in words
    temps.append(desc[-1])        #get the last item in sentence // temp
print(temps)

##convert fahrenheit to C
#°C = (°F − 32) / 1,8
temps_in_C = []
for temp in temps:
    new_temp = (int(temp)-32)/ 1.8
    new_temp = round(new_temp,2)
    temps_in_C.append(f'{new_temp} °C')
print(temps_in_C)
# Out:
# ['66', '48', '61', '46', '69', '47', '74', '49', '69', '49', '66', '48', '69']
# ['18.89 °C', '8.89 °C', '16.11 °C', '7.78 °C', '20.56 °C', '8.33 °C', '23.33 °C', '9.44 °C', '20.56 °C', '9.44 °C', '18.89 °C', '8.89 °C', '20.56 °C']

# %%
today = date.today()
print(today)
seventh_day = today + datetime.timedelta(days=6)         # get the end day for date_range
date_range = pd.date_range(start=today, end=seventh_day) #get date range for 7 days
print(date_range)
date_range = date_range.repeat(2) #reapeat twice
date_range = date_range[:-1]
print(date_range)
# Out:
# 2021-03-24
# DatetimeIndex(['2021-03-24', '2021-03-25', '2021-03-26', '2021-03-27',
#                '2021-03-28', '2021-03-29', '2021-03-30'],
#               dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2021-03-24', '2021-03-24', '2021-03-25', '2021-03-25',
#                '2021-03-26', '2021-03-26', '2021-03-27', '2021-03-27',
#                '2021-03-28', '2021-03-28', '2021-03-29', '2021-03-29',
#                '2021-03-30'],
#               dtype='datetime64[ns]', freq=None)

# %%
low_high = ['high','low']*7 #creating low& high list
low_high = low_high[:-1]

# %%
df = pd.DataFrame({
    'days':days,
    'temps_in_C':temps_in_C,
    'low_high':low_high,
    'description':description
                  }, index=date_range)
#df['date'] = date_range

# %%
display(df)
# Out:
#                       days temps_in_C low_high  \
# 2021-03-24  This Afternoon   18.89 °C     high
# 2021-03-24         Tonight    8.89 °C      low
# 2021-03-25        Thursday   16.11 °C     high
# 2021-03-25  Thursday Night    7.78 °C      low
# 2021-03-26          Friday   20.56 °C     high
# 2021-03-26    Friday Night    8.33 °C      low
# 2021-03-27        Saturday   23.33 °C     high
# 2021-03-27  Saturday Night    9.44 °C      low
# 2021-03-28          Sunday   20.56 °C     high
# 2021-03-28    Sunday Night    9.44 °C      low
# 2021-03-29          Monday   18.89 °C     high
# 2021-03-29    Monday Night    8.89 °C      low
# 2021-03-30         Tuesday   20.56 °C     high
#
#                                                   description
# 2021-03-24  Mostly sunny, with a high near 66. North wind ...
# 2021-03-24  Partly cloudy, with a low around 48. West wind...
# 2021-03-25  Sunny, with a high near 61. West wind 7 to 17 ...
# 2021-03-25  Clear, with a low around 46. Northwest wind 5 ...
# 2021-03-26  Sunny, with a high near 69. North wind 8 to 10...
# 2021-03-26                       Clear, with a low around 47.
# 2021-03-27                        Sunny, with a high near 74.
# 2021-03-27                       Clear, with a low around 49.
# 2021-03-28                        Sunny, with a high near 69.
# 2021-03-28                Mostly clear, with a low around 49.
# 2021-03-29                        Sunny, with a high near 66.
# 2021-03-29                       Clear, with a low around 48.
# 2021-03-30                        Sunny, with a high near 69.
